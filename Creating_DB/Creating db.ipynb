# %%
import pandas as pd
import sqlalchemy
import numpy as np

# %%
db_path = 'indian_food.sqlite'
csv_path = 'indian_food.csv'

# %%
engine = sqlalchemy.create_engine('sqlite+pysqlite:///' + db_path)
metadata = sqlalchemy.MetaData()

# %%
df = pd.read_csv(csv_path)
df.replace(-1, np.nan, inplace=True)
df.replace('-1', np.nan, inplace=True)
df.dropna(inplace=True)

# %%
dump = ['''
-- Table: Course
CREATE TABLE IF NOT EXISTS Course (
    course_id integer NOT NULL CONSTRAINT Course_pk PRIMARY KEY,
    course_name varchar(12) NOT NULL
);
''',
'''
-- Table: Diet
CREATE TABLE IF NOT EXISTS Diet (
    diet_id integer NOT NULL CONSTRAINT Diet_pk PRIMARY KEY,
    diet_name character(15) NOT NULL
);
''',
'''
-- Table: Flavor_profile
CREATE TABLE IF NOT EXISTS Flavor_profile (
    flavor_id integer NOT NULL CONSTRAINT Flavor_profile_pk PRIMARY KEY,
    flavor_name varchar(7) NOT NULL
);
''',
'''
-- Table: Food
CREATE TABLE IF NOT EXISTS Food (
    food_id integer NOT NULL CONSTRAINT Food_pk PRIMARY KEY,
    food_name varchar(30) NOT NULL,
    ingredients varchar(100) NOT NULL,
    prep_time integer NOT NULL,
    cook_time integer NOT NULL,
    state_id integer NOT NULL,
    region_id integer NOT NULL,
    diet_id integer NOT NULL,
    flavor_id integer NOT NULL,
    course_id integer NOT NULL,
    CONSTRAINT Food_State FOREIGN KEY (state_id)
    REFERENCES State (state_id),
    CONSTRAINT Food_Region FOREIGN KEY (region_id)
    REFERENCES Region (region_id),
    CONSTRAINT Food_Diet FOREIGN KEY (diet_id)
    REFERENCES Diet (diet_id),
    CONSTRAINT Food_Flavor_profile FOREIGN KEY (flavor_id)
    REFERENCES Flavor_profile (flavor_id),
    CONSTRAINT Food_Course FOREIGN KEY (course_id)
    REFERENCES Course (course_id)
);
''',
'''
-- Table: Region
CREATE TABLE IF NOT EXISTS Region (
    region_id integer NOT NULL CONSTRAINT Region_pk PRIMARY KEY,
    region_name varchar(11) NOT NULL
);
''',
'''
-- Table: State
CREATE TABLE IF NOT EXISTS State (
    state_id integer NOT NULL CONSTRAINT State_pk PRIMARY KEY,
    state_name varchar(15) NOT NULL,
    region_id integer NOT NULL,
    CONSTRAINT State_Region FOREIGN KEY (region_id)
    REFERENCES Region (region_id)
);
'''
]

# %%
with engine.connect() as conn:
    for statement in dump:
        conn.execute(statement)

# %%
values = df['diet'].unique()
tablename = 'Diet'

with engine.connect() as conn: 
    table = sqlalchemy.Table(tablename, metadata, autoload=True, autoload_with=engine)
    query = sqlalchemy.insert(table)
    for v in values:
        conn.execute(query, {'diet_name': v})

# %%
with engine.connect() as conn:
    query = sqlalchemy.select([metadata.tables['Diet']])
    result = conn.execute(query).fetchall()
    for r in result:
        print(r)
# Out:
# (1, 'vegetarian')
# (2, 'non vegetarian')

# %%
values = df['flavor_profile'].unique()
tablename = 'Flavor_profile'

with engine.connect() as conn: 
    table = sqlalchemy.Table(tablename, metadata, autoload=True, autoload_with=engine)
    query = sqlalchemy.insert(table)
    for v in values:
        conn.execute(query, {'flavor_name': v})

# %%
with engine.connect() as conn:
    query = sqlalchemy.select([metadata.tables['Flavor_profile']])
    result = conn.execute(query).fetchall()
    for r in result:
        print(r)
# Out:
# (1, 'sweet')
# (2, 'spicy')
# (3, 'bitter')
# (4, 'sour')

# %%
values = df['course'].unique()
tablename = 'Course'

with engine.connect() as conn: 
    table = sqlalchemy.Table(tablename, metadata, autoload=True, autoload_with=engine)
    query = sqlalchemy.insert(table)
    for v in values:
        conn.execute(query, {'course_name': v})

# %%
with engine.connect() as conn:
    query = sqlalchemy.select([metadata.tables['Course']])
    result = conn.execute(query).fetchall()
    for r in result:
        print(r)
# Out:
# (1, 'dessert')
# (2, 'main course')
# (3, 'starter')
# (4, 'snack')

# %%
values = df['region'].unique()
tablename = 'Region'

with engine.connect() as conn: 
    table = sqlalchemy.Table(tablename, metadata, autoload=True, autoload_with=engine)
    query = sqlalchemy.insert(table)
    for v in values:
        conn.execute(query, {'region_name': v})

# %%
with engine.connect() as conn:
    query = sqlalchemy.select([metadata.tables['Region']])
    result = conn.execute(query).fetchall()
    for r in result:
        print(r)
# Out:
# (1, 'East')
# (2, 'West')
# (3, 'North')
# (4, 'North East')
# (5, 'South')
# (6, 'Central')

# %%
def getId(table, item, col_id=None, col_name=None):
    if col_id is None:
        col_id = table.lower() + '_id'
    if col_name is None:
        col_name = table.lower() + '_name'
    table = metadata.tables[table]
    query = sqlalchemy.select([table.c[col_id]]).select_from(table).where(table.c[col_name] == item)
    with engine.connect() as conn:
        result = conn.execute(query).fetchone()
    return result[0]

# %%
values = df[['state', 'region']].drop_duplicates()
tablename = 'State'

with engine.connect() as conn: 
    table = sqlalchemy.Table(tablename, metadata, autoload=True, autoload_with=engine)
    query = sqlalchemy.insert(table)
    for v in values.values:
        state_name = v[0]
        region_id = int(getId('Region', v[1]))
        conn.execute(query, {'state_name': state_name, 'region_id': region_id})

# %%
with engine.connect() as conn: 
    query = sqlalchemy.select([metadata.tables['State']])
    result = conn.execute(query).fetchall()
    for r in result:
        print(r)
# Out:
# (1, 'West Bengal', 1)
# (2, 'Rajasthan', 2)
# (3, 'Punjab', 3)
# (4, 'Uttar Pradesh', 3)
# (5, 'Odisha', 1)
# (6, 'Maharashtra', 2)
# (7, 'Uttarakhand', 3)
# (8, 'Assam', 4)
# (9, 'Bihar', 3)
# (10, 'Andhra Pradesh', 5)
# (11, 'Karnataka', 5)
# (12, 'Telangana', 5)
# (13, 'Kerala', 5)
# (14, 'Tamil Nadu', 5)
# (15, 'Gujarat', 2)
# (16, 'Manipur', 4)
# (17, 'Nagaland', 4)
# (18, 'NCT of Delhi', 3)
# (19, 'Jammu & Kashmir', 3)
# (20, 'Chhattisgarh', 6)
# (21, 'Haryana', 3)
# (22, 'Madhya Pradesh', 6)
# (23, 'Goa', 2)

# %%
values = df
tablename = 'Food'

with engine.connect() as conn: 
    table = sqlalchemy.Table(tablename, metadata, autoload=True, autoload_with=engine)
    query = sqlalchemy.insert(table)
    for v in values.values:
        
        food_name = v[0]
        ingredients = v[1]
        diet_id = int(getId('Diet', v[2]))
        prep_time = int(v[3])
        cook_time = int(v[4])
        flavor_id = int(getId('Flavor_profile', v[5], col_id='flavor_id', col_name='flavor_name'))
        course_id = int(getId('Course', v[6]))
        state_id = int(getId('State', v[7]))
        region_id = int(getId('Region', v[8]))
        
        dic = {
            'food_name': food_name,
            'ingredients': ingredients,
            'diet_id': diet_id,
            'prep_time': prep_time,
            'cook_time': cook_time,
            'flavor_id': flavor_id,
            'course_id': course_id,
            'state_id': state_id,
            'region_id': region_id
        }
        
        conn.execute(query, dic)

# %%
with engine.connect() as conn: 
    query = sqlalchemy.select([metadata.tables['Food']])
    result = conn.execute(query).fetchall()
    for r in result:
        print(r)
# Out:
# (1, 'Balu shahi', 'Maida flour, yogurt, oil, sugar', 45, 25, 1, 1, 1, 1, 1)
# (2, 'Boondi', 'Gram flour, ghee, sugar', 80, 30, 2, 2, 1, 1, 1)
# (3, 'Gajar ka halwa', 'Carrots, milk, sugar, ghee, cashews, raisins', 15, 60, 3, 3, 1, 1, 1)
# (4, 'Ghevar', 'Flour, ghee, kewra, milk, clarified butter, sugar, almonds, pistachio, saffron, green cardamom', 15, 30, 2, 2, 1, 1, 1)
# (5, 'Gulab jamun', 'Milk powder, plain flour, baking powder, ghee, milk, sugar, water, rose water', 15, 40, 1, 1, 1, 1, 1)
# (6, 'Imarti', 'Sugar syrup, lentil flour', 10, 50, 1, 1, 1, 1, 1)
# (7, 'Jalebi', 'Maida, corn flour, baking soda, vinegar, curd, water, turmeric, saffron, cardamom', 10, 50, 4, 3, 1, 1, 1)
# (8, 'Kalakand', 'Milk, cottage cheese, sugar', 20, 30, 1, 1, 1, 1, 1)
# (9, 'Lassi', 'Yogurt, milk, nuts, sugar', 5, 5, 3, 3, 1, 1, 1)
# (10, 'Petha', 'Firm white pumpkin, sugar, kitchen lime, alum powder', 10, 30, 4, 3, 1, 1, 1)
# (11, 'Phirni', 'Rice, sugar, nuts', 30, 20, 5, 1, 1, 1, 1)
# (12, 'Rabri', 'Condensed milk, sugar, spices, nuts', 10, 45, 4, 3, 1, 1, 1)
# (13, 'Sheera', 'Semolina, ghee, nuts, milk', 10, 25, 6, 2, 1, 1, 1)
# (14, 'Singori', 'Khoa, coconut, molu leaf', 10, 20, 7, 3, 1, 1, 1)
# (15, 'Sohan halwa', 'Corn flour, ghee, dry fruits', 10, 60, 4, 3, 1, 1, 1)
# (16, 'Chhena jalebi', 'Chhena, sugar, ghee', 10, 50, 5, 1, 1, 1, 1)
# (17, 'Chhena poda', 'Sugar, chenna cheese', 10, 45, 5, 1, 1, 1, 1)
# (18, 'Cham cham', 'Flour, cream, sugar, saffron, lemon juice, coconut flakes', 40, 60, 1, 1, 1, 1, 1)
# (19, 'Kheer sagar', 'Chenna, condensed milk, sugar, saffron, cardamom', 25, 60, 5, 1, 1, 1, 1)
# (20, 'Ledikeni', 'Chhena, sugar, ghee', 45, 45, 1, 1, 1, 1, 1)
# (21, 'Lyangcha', 'Flour, fried milk power, sugar syrup', 20, 30, 8, 4, 1, 1, 1)
# (22, 'Malapua', 'Yoghurt, refined flour, ghee, fennel seeds', 10, 120, 9, 3, 1, 1, 1)
# (23, 'Mihidana', 'Besan flour, sugar, ghee', 15, 30, 1, 1, 1, 1, 1)
# (24, 'Misti doi', 'Milk, jaggery', 480, 30, 1, 1, 1, 1, 1)
# (25, 'Pantua', 'Chhena, sugar, ghee, flour', 45, 45, 1, 1, 1, 1, 1)
# (26, 'Pithe', 'Rice flour, wheat flour', 15, 35, 8, 4, 1, 1, 1)
# (27, 'Rasabali', 'Chenna, sweetened milk', 15, 30, 5, 1, 1, 1, 1)
# (28, 'Ras malai', 'Chhena, reduced milk, pistachio', 180, 60, 1, 1, 1, 1, 1)
# (29, 'Rasgulla', 'Chhena, sugar, cardamom', 10, 90, 1, 1, 1, 1, 1)
# (30, 'Sandesh', 'Milk, sugar, saffron, cardamom', 30, 20, 1, 1, 1, 1, 1)
# (31, 'Adhirasam', 'Rice flour, jaggery, ghee, vegetable oil, elachi', 10, 50, 1, 1, 1, 1, 1)
# (32, 'Ariselu', 'Rice flour, jaggery, ghee', 15, 75, 10, 5, 1, 1, 1)
# (33, 'Bandar laddu', 'Besan, jaggery, cardamom powder, ghee, cashews and raisins, jaggery syrup, sugar', 5, 35, 10, 5, 1, 1, 1)
# (34, 'Chikki', 'Peanuts, jaggery', 10, 20, 6, 2, 1, 1, 1)
# (35, 'Dharwad pedha', 'Milk, Sugar, Dharwadi buffalo milk', 20, 60, 11, 5, 1, 1, 1)
# (36, 'Double ka meetha', 'Loaf bread, milk', 20, 30, 12, 5, 1, 1, 1)
# (37, 'Gavvalu', 'Rice flour, sugar, salt, ghee, semolina', 10, 30, 10, 5, 1, 1, 1)
# (38, 'Kakinada khaja', 'Wheat flour, sugar', 10, 30, 10, 5, 1, 1, 1)
# (39, 'Kuzhi paniyaram', 'Black lentils, rice', 10, 20, 13, 5, 1, 1, 1)
# (40, 'Mysore pak', 'Besan flour, semolina, mung bean, jaggery, coconut, skimmed milk powder, sugar, ghee', 5, 20, 11, 5, 1, 1, 1)
# (41, 'Obbattu holige', 'Maida flour, turmeric, coconut, chickpeas, jaggery, ghee, cardamom', 180, 60, 11, 5, 1, 1, 2)
# (42, 'Palathalikalu', 'Rice flour, milk', 10, 25, 10, 5, 1, 1, 1)
# (43, 'Poornalu', 'Chana dal, jaggery', 240, 60, 10, 5, 1, 1, 1)
# (44, 'Pongal', 'Rice, jaggery, cashews, ghee', 5, 20, 14, 5, 1, 1, 1)
# (45, 'Pootharekulu', 'Rice flour, powdered sugar, ghee', 10, 60, 10, 5, 1, 1, 1)
# (46, 'Qubani ka meetha', 'Apricots, sugar syrup', 10, 20, 12, 5, 1, 1, 1)
# (47, 'Sheer korma', 'Vermicelli pudding, milk', 10, 20, 12, 5, 1, 1, 1)
# (48, 'Unni Appam', 'Rice flour, banana, jaggery, coconut', 10, 20, 14, 5, 1, 1, 1)
# (49, 'Kajjikaya', 'Rice flour, jaggery, coconut', 40, 15, 10, 5, 1, 1, 1)
# (50, 'Anarsa', 'Rice flour, jaggery, khus-khus seeds', 10, 50, 6, 2, 1, 1, 1)
# (51, 'Basundi', 'Sugar, milk, nuts', 10, 35, 15, 2, 1, 1, 1)
# (52, 'Dhondas', 'Cucumber, rava', 10, 50, 6, 2, 1, 1, 1)
# (53, 'Doodhpak', 'Milk, rice, sugar, dry fruits', 10, 60, 15, 2, 1, 1, 1)
# (54, 'Mahim halwa', 'Semolina, sugar', 10, 25, 6, 2, 1, 1, 1)
# (55, 'Modak', 'Rice flour, coconut, jaggery ', 10, 15, 6, 2, 1, 1, 1)
# (56, 'Shankarpali', 'Sugar, ghee, maida flour, semolina', 10, 35, 6, 2, 1, 1, 1)
# (57, 'Shrikhand', 'Curd, sugar, saffron, cardamom', 10, 720, 6, 2, 1, 1, 1)
# (58, 'Sutar feni', 'Maida, sugar, ghee', 15, 55, 6, 2, 1, 1, 1)
# (59, 'Maach Jhol', 'Fish, potol, tomato, chillies, ginger, garlic', 10, 40, 8, 4, 2, 2, 2)
# (60, 'Chak Hao Kheer', 'Rice, milk, sugar, cardamom', 240, 45, 16, 4, 1, 1, 1)
# (61, 'Galho', 'Rice, axone, salt, water, chillies, pork', 5, 15, 17, 4, 2, 2, 2)
# (62, 'Aloo gobi', 'Cauliflower, potato, garam masala, turmeric, curry leaves', 10, 20, 3, 3, 1, 2, 2)
# (63, 'Aloo tikki', 'Rice flour, potato, bread crumbs, garam masala, salt', 5, 20, 3, 3, 1, 2, 2)
# (64, 'Aloo matar', 'Potato, peas, chillies, ginger, garam masala, garlic', 5, 40, 3, 3, 1, 2, 2)
# (65, 'Aloo methi', 'Potato, fenugreek leaves, chillies, salt, oil', 10, 40, 3, 3, 1, 3, 2)
# (66, 'Aloo shimla mirch', 'Potato, shimla mirch, garam masala, amchur powder, salt', 10, 40, 3, 3, 1, 2, 2)
# (67, 'Bhatura', 'Chole, rava, yogurt, plain flour, baking soda', 20, 20, 3, 3, 1, 2, 2)
# (68, 'Bhindi masala', 'Ladies finger, garam masala, kasuri methi, tomatoes, chili powder', 20, 30, 3, 3, 1, 2, 2)
# (69, 'Biryani', 'Chicken thighs, basmati rice, star anise, sweet, green chillies', 30, 120, 12, 5, 2, 2, 2)
# (70, 'Butter chicken', 'Chicken, greek yogurt, cream, garam masala powder, cashew nuts, butter', 10, 35, 18, 3, 2, 2, 2)
# (71, 'Chana masala', 'Chickpeas, tomato paste, garam masala, ginger, red onion, avocado oil', 20, 30, 3, 3, 1, 2, 2)
# (72, 'Chicken razala', 'Chicken, dahi, sesame seeds, garam masala powder, cashew nuts, saffron', 10, 35, 1, 1, 2, 2, 2)
# (73, 'Chicken Tikka masala', 'Naan bread, tomato sauce, skinless chicken breasts, heavy cream, garam masala', 10, 50, 3, 3, 2, 2, 2)
# (74, 'Chicken Tikka', 'Chicken, whole wheat bread, rice flour, garam masala powder, whole egg', 120, 45, 3, 3, 2, 2, 3)
# (75, 'Chole bhature', 'Chole, bhatura, garam masala, bay leaf, cinnamon stick', 20, 30, 3, 3, 1, 2, 2)
# (76, 'Daal baati churma', 'Moong dal, masoor dal, chana dal, wheat flour, almond', 10, 90, 2, 2, 1, 2, 2)
# (77, 'Daal puri', 'Moong dal, garam masala powder, garlic, green chilli, all purpose flour', 30, 30, 1, 1, 1, 2, 2)
# (78, 'Dal makhani ', 'Red kidney beans, urad dal, cream, garam masala, chili powder', 10, 60, 3, 3, 1, 1, 2)
# (79, 'Dal tadka', 'Pigeon peas, garam masala, ginger, red onion, kasuri methi', 10, 30, 3, 3, 1, 2, 2)
# (80, 'Dum aloo', 'Baby potatoes, garam masala, cashew nuts, kasuri methi, tomatoes', 20, 50, 19, 3, 1, 2, 2)
# (81, 'Poha', 'Beaten rice flakes, potato, curry leaves, green chilies, lemon juice', 20, 30, 6, 2, 1, 2, 4)
# (82, 'Fara', 'Chana dal, whole wheat flour, arhar dal, white urad dal, garam masala powder', 10, 60, 20, 6, 1, 2, 4)
# (83, 'Kachori', 'Moong dal, rava, garam masala, dough, fennel seeds', 30, 60, 4, 3, 1, 2, 4)
# (84, 'Kadai paneer', 'Cottage cheese, bell peppers, gravy, garam masala, cashew nuts', 20, 30, 3, 3, 1, 2, 2)
# (85, 'Kadhi pakoda', 'Besan, garam masala powder, gram flour, ginger, curry leaves', 10, 60, 21, 3, 1, 2, 2)
# (86, 'Karela bharta', 'Bitter gourd, fennel, garam masala powder, chili powder, amchur powder', 20, 50, 3, 3, 1, 3, 2)
# (87, 'Kofta', 'Paneer, potato, cream, corn flour, garam masala', 20, 40, 4, 3, 1, 2, 2)
# (88, 'Lauki ke kofte', 'Bottle gourd, garam masala powder, gram flour, ginger, chillies', 20, 40, 4, 3, 1, 2, 2)
# (89, 'Litti chokha', 'Wheat flour, roasted gram flour, tomato, nigella seeds, chilli', 45, 60, 9, 3, 1, 2, 2)
# (90, 'Makki di roti sarson da saag', 'Palak, makki atta, mustard green, garam masala, ginger', 25, 30, 3, 3, 1, 2, 2)
# (91, 'Misi roti', 'Whole wheat flour, chickpea flour, green chilies', 30, 30, 3, 3, 1, 2, 2)
# (92, 'Mushroom do pyaza', 'Mushroom, malai, garam masala, ginger, capsicum', 10, 30, 3, 3, 1, 2, 2)
# (93, 'Mushroom matar', 'Canned coconut milk, frozen green peas, wild mushrooms, garam masala, tomatoes', 10, 30, 3, 3, 1, 2, 2)
# (94, 'Navrattan korma', 'Green beans, potatoes, khus khus, low fat, garam masala powder', 25, 40, 4, 3, 1, 2, 2)
# (95, 'Palak paneer', 'Cottage cheese, palak, cream, garam masala, butter', 20, 40, 3, 3, 1, 2, 2)
# (96, 'Paneer butter masala', 'Paneer, whipping cream, garam masala, cashew nuts, butter', 20, 40, 3, 3, 1, 2, 2)
# (97, 'Paneer tikka masala', 'Paneer, greek yogurt, tandoori masala, cream, bell pepper', 20, 40, 3, 3, 1, 2, 2)
# (98, 'Paratha', 'Wheat flour, butter, potato, coriander', 15, 45, 3, 3, 1, 2, 2)
# (99, 'Pattor', 'Arbi ke patte, sesame seeds, gur, bengal gram flour, imli', 10, 30, 2, 2, 1, 2, 2)
# (100, 'Pindi chana', 'Fennel, tea bags, tomato, kasuri methi, cinnamon', 500, 120, 3, 3, 1, 2, 2)
# (101, 'Sattu ki roti', 'Sattu, atta, dough, filling, mustard oil', 10, 20, 9, 3, 1, 2, 2)
# (102, 'Shahi paneer', 'Cottage cheese, malai, garam masala, ginger, tomato', 20, 40, 3, 3, 1, 2, 2)
# (103, 'Shahi tukra', 'Rose water, milk, white bread slices, saffron, almonds', 10, 30, 12, 5, 1, 1, 1)
# (104, 'Vegetable jalfrezi', 'Baby corn, french beans, garam masala, ginger, carrot', 10, 30, 3, 3, 1, 2, 2)
# (105, 'Tandoori Chicken', 'Greek yogurt, garam masala, kasuri methi, marinade, mustard oil', 240, 30, 3, 3, 2, 2, 2)
# (106, 'Tandoori Fish Tikka', 'Chickpea flour, biryani masala powder, yogurt, fish fillets, green bell pepper', 240, 30, 3, 3, 2, 2, 3)
# (107, 'Attu', 'Whole wheat flour, arhar dal, ginger, kala jeera, green chilli', 150, 25, 10, 5, 1, 2, 4)
# (108, 'Avial', 'Raw banana, elephant foot yam, long beans, tindora, urad dal', 30, 45, 13, 5, 1, 2, 2)
# (109, 'Bisi bele bath', 'Split pigeon peas, chana dal, urad dal, green peas, french beans', 30, 45, 11, 5, 1, 2, 2)
# (110, 'Currivepillai sadam ', 'Chana dal, urad dal, fresh coconut, sesame seeds, curry leaves', 10, 20, 14, 5, 1, 2, 2)
# (111, 'Idiappam', 'Rice flour, hot water, grated coconut', 120, 30, 14, 5, 1, 2, 4)
# (112, 'Keerai kootu', 'Moong dal, chana dal, spinach, urad dal, coconut oil', 20, 30, 14, 5, 1, 2, 2)
# (113, 'Keerai sadam', 'Greens, tomato, mustard seeds, fenugreek seeds', 10, 20, 14, 5, 1, 2, 2)
# (114, 'Keerai poriyal', 'Amaranth leaves, split urad dal, mustard seeds, grated coconut, red chili', 20, 30, 14, 5, 1, 2, 2)
# (115, 'Beef Fry', 'Beef, coconut, garam masala, curry leaves, green chilies, chili powder', 10, 60, 13, 5, 2, 2, 2)
# (116, 'Kootu', 'Chana dal, urad dal, potato, beans, peas', 10, 15, 14, 5, 1, 2, 2)
# (117, 'Kos kootu', 'Moong dal, chana dal, cabbage, tamarind, curry leaves', 10, 20, 14, 5, 1, 2, 2)
# (118, 'Koshambri', 'Moong dal, cucumber, curry leaves, green chili, lemon juice', 10, 20, 11, 5, 1, 2, 2)
# (119, 'Kothamali sadam', 'Chana dal, urad dal, gooseberry, raw rice, curry leaves', 10, 20, 14, 5, 1, 2, 2)
# (120, 'Kuzhakkattai', 'Sesame oil, raw rice, jaggery, grated coconut', 10, 90, 14, 5, 1, 2, 2)
# (121, 'Kuzhambu', 'Pearl onions, urad dal, drumsticks, tomato, curry leaves', 5, 30, 14, 5, 1, 2, 2)
# (122, 'Papadum', 'Lentils, black pepper, vegetable oil', 5, 5, 13, 5, 1, 2, 4)
# (123, 'Pesarattu', 'Green moong beans, rice flour', 120, 20, 10, 5, 1, 2, 4)
# (124, 'Chicken Varuval', 'Meat curry powder, chicken chunks, ginger, tomato, cinnamon', 10, 35, 14, 5, 2, 2, 2)
# (125, 'Amti', 'Kala masala, arhar dal, curry leaves, mustard seeds, hot water', 10, 45, 6, 2, 1, 2, 2)
# (126, 'Zunka', 'Gram flour, mustard, garlic, turmeric, red chilli', 10, 25, 6, 2, 1, 2, 2)
# (127, 'Saath', 'Urad dal, potatoes, wheat flour, sooji', 20, 40, 15, 2, 1, 2, 2)
# (128, 'Bajri no rotlo', 'Wheat flour, pearl millet flour, hot water', 10, 10, 15, 2, 1, 2, 2)
# (129, 'Coconut vadi', 'Condensed milk, mawa, desiccated coconut, almonds, cashews', 20, 30, 6, 2, 1, 1, 1)
# (130, 'Chakali', 'Rice flour, sesame, plain flour, turmeric, red chilli', 10, 40, 6, 2, 1, 2, 4)
# (131, 'Chevdo', 'Citric acid, fry, raisins, sugar, chana daal', 20, 30, 15, 2, 1, 2, 4)
# (132, 'Chorafali', 'Urad dal, bengal gram flour, dried mango, baking soda, black salt', 5, 15, 15, 2, 1, 2, 4)
# (133, 'Daal Dhokli', 'Whole wheat flour, dal, kokum, gur, bengal gram flour', 20, 30, 15, 2, 1, 2, 2)
# (134, 'Kutchi dabeli', 'Pav, aloo, peanut, pomegranate, star anise', 30, 10, 15, 2, 1, 2, 4)
# (135, 'Dhokla', 'Rava, coconut, gram flour, mustard, sesame', 10, 20, 15, 2, 1, 2, 4)
# (136, 'Dudhi halwa', 'Bottle gourd, green, raisins, sugar, clarified butter', 15, 30, 15, 2, 1, 1, 1)
# (137, 'Gatta curry', 'Yogurt, besan, sauce, garam masala powder, gram flour', 10, 20, 2, 2, 1, 2, 2)
# (138, 'Gud papdi', 'Wheat flour, jaggery, clarified butter, sliced almonds', 10, 20, 15, 2, 1, 1, 1)
# (139, 'Handwo', 'Bottle gourd, chana dal, cabbage, urad dal, toor dal', 20, 30, 15, 2, 1, 2, 4)
# (140, 'Jeera Aloo', 'Green chilies, lemon juice, chili powder, boiled potatoes', 10, 30, 15, 2, 1, 2, 2)
# (141, 'Keri no ras', 'Mango, sugar', 10, 10, 15, 2, 1, 4, 2)
# (142, 'Khakhra', 'Whole wheat flour, low fat, bengal gram flour', 20, 40, 15, 2, 1, 2, 4)
# (143, 'Khandvi', 'Green chili paste, white sesame seeds, gram flour, curry leaves, green chili', 20, 45, 15, 2, 1, 2, 4)
# (144, 'Kombdi vade', 'Rice flour, urad dal, wheat flour, gram flour, turmeric', 10, 25, 6, 2, 1, 2, 4)
# (145, 'Laapsi', 'Cinnamon, jaggery, clarified butter, dry roasted', 10, 40, 22, 6, 1, 2, 2)
# (146, 'Koshimbir', 'Cucumber, carrot, tomatoes, cilantro', 10, 10, 6, 2, 1, 2, 2)
# (147, 'Methi na Gota', 'Rava, gram flour, lemon juice, turmeric, fenugreek leaves', 15, 30, 15, 2, 1, 3, 2)
# (148, 'Mohanthal', 'Rose water, pistachio, badam, bengal gram flour, saffron', 5, 45, 15, 2, 1, 1, 1)
# (149, 'Muthiya', 'Bottle gourd, whole wheat flour, rava, sesame seeds, bengal gram flour', 15, 30, 15, 2, 1, 3, 4)
# (150, 'Patra', 'Arbi ke patte, sesame seeds, gur, bengal gram flour, imli', 10, 40, 15, 2, 1, 2, 4)
# (151, 'Pav Bhaji', 'Pav bhaji masala, gobi, potatoes, green peas, dinner rolls', 20, 40, 6, 2, 1, 2, 2)
# (152, 'Puri Bhaji', 'Aloo, urad dal, mustard, ginger, curry leaves', 10, 30, 6, 2, 1, 2, 2)
# (153, 'Sabudana Khichadi', 'Raw peanuts, sabudana, lemon, avocado oil, curry leaves, green chili', 70, 30, 6, 2, 1, 2, 4)
# (154, 'Sev khamani', 'Khaman, pomegranate, sev, powdered sugar, garlic', 20, 30, 15, 2, 1, 2, 2)
# (155, 'Sev tameta', 'Sev, ginger, tomato, sugar', 20, 30, 15, 2, 1, 2, 2)
# (156, 'Namakpara', 'Wheat flour, baking soda, all purpose flour, black pepper, sunflower oil', 10, 35, 15, 2, 1, 2, 4)
# (157, 'Sukhdi', 'Whole wheat flour, gur, clarified butter', 10, 20, 6, 2, 1, 1, 1)
# (158, 'Surnoli', 'Rice flakes, yogurt, raw rice, jaggery, grated coconut', 60, 10, 6, 2, 1, 2, 4)
# (159, 'Thalipeeth', 'Whole wheat flour, rice flour, pearl millet flour, sorghum flour, sesame seeds', 25, 30, 6, 2, 1, 2, 2)
# (160, 'Undhiyu', 'Sweet potato, surti papdi, baby potatoes, valor papdi, green peas', 25, 60, 15, 2, 1, 2, 2)
# (161, 'Veg Kolhapuri', 'Gobi, potato, beans, khus khus, coconut', 20, 30, 6, 2, 1, 2, 2)
# (162, 'Vindaloo', 'Chicken, coconut oil, wine vinegar, ginger, green, cinnamon', 10, 40, 23, 2, 2, 2, 2)
# (163, 'Lilva Kachori', 'Green garlic chutney, fresh green peas, ginger, lemon juice, plain flour', 30, 6, 15, 2, 1, 2, 4)
# (164, 'Khichu', 'Rice flour, sesame seeds, baking soda, peanut oil', 5, 10, 15, 2, 1, 2, 4)
# (165, 'Thepla', 'Chickpea flour, methi leaves, jowar flour, wheat flour', 15, 30, 15, 2, 1, 2, 4)
# (166, 'Khaman', 'Yogurt, fresh coconut, sesame seeds, semolina, gram flour', 10, 20, 15, 2, 1, 2, 4)
# (167, 'Turiya Patra Vatana sabji', 'Ridge gourd, baking soda, sugar, grated coconut, peas', 35, 40, 15, 2, 1, 2, 2)
# (168, 'Churma Ladoo', 'Whole wheat flour, khus khus, sesame seeds, dry coconut, gur', 12, 40, 2, 2, 1, 1, 1)
# (169, 'Gheela Pitha', 'Sticky rice, rice flour, jaggery, orange rind', 10, 30, 8, 4, 1, 1, 1)
# (170, 'Alu Pitika', 'Potatoes, mustard oil, fish, green chillies', 5, 20, 8, 4, 2, 2, 2)
# (171, 'Masor tenga', 'Ridge gourd, fish, lemon, tomatoes, mustard oil', 15, 25, 8, 4, 2, 2, 2)
# (172, 'Chingri malai curry', 'Coconut milk, lobster, fresh green chilli, ginger, red onion', 10, 40, 1, 1, 2, 2, 2)
# (173, 'Goja', 'Baking soda, clarified butter, oil, all purpose flour', 20, 60, 1, 1, 1, 1, 1)
# (174, 'Haq Maas', 'Lamb, garam masala powder, curd, turmeric, bay leaf', 20, 40, 8, 4, 2, 2, 2)
# (175, 'Mishti Chholar Dal', 'Chana dal, fresh coconut, ginger, cinnamon, raisins', 10, 30, 1, 1, 1, 1, 2)
# (176, 'Prawn malai curry', 'Coconut milk, prawns, garlic, turmeric, sugar', 15, 50, 1, 1, 2, 2, 2)
# (177, 'Shukto', 'Green beans, bitter gourd, ridge gourd, banana, brinjal', 10, 20, 1, 1, 1, 2, 2)
# (178, 'Til Pitha', 'Glutinous rice, black sesame seeds, gur', 5, 30, 8, 4, 1, 1, 1)
# (179, 'Bebinca', 'Coconut milk, egg yolks, clarified butter, all purpose flour', 20, 60, 23, 2, 1, 1, 1)
# (180, 'Mawa Bati', 'Milk powder, dry fruits, arrowroot powder, all purpose flour', 20, 45, 22, 6, 1, 1, 1)
